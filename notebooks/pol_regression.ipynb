# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score

# %%
## dados
x = 6 * np.random.rand(200, 1) - 3
y = 0.8 * x**2 + 0.9*x + 2 + np.random.randn(200, 1)

## plotando os dados
f, ax = plt.subplots()
ax.scatter(x,y)
ax.set_xlabel("X")
ax.set_ylabel("Y")
plt.show()

# %%
lr = LinearRegression()
lr.fit(x,y)
y_pred = lr.predict(x)
print(r2_score(y, y_pred))
# Out:
# 0.36634338901257313

# %%
f, ax = plt.subplots()

ax.scatter(x,y)

ax.plot(x,y_pred,color='r')
ax.set_xlabel("X")
ax.set_ylabel("Y")
plt.show()

# %% [markdown]
# ## Polynomial Regression

# %%
poly = PolynomialFeatures(degree=2)
poly.fit(x_train)
# Out:
# PolynomialFeatures()

# %%
x_poly = poly.transform(x)

# %%
x[:10]
# Out:
# array([[ 2.78253948],
#        [ 2.01072375],
#        [ 2.257379  ],
#        [-0.61073606],
#        [-1.65546619],
#        [ 0.29897899],
#        [ 2.51491446],
#        [-1.84028855],
#        [ 2.03696077],
#        [-0.77290723]])

# %%
x_poly[:10]
# Out:
# array([[ 1.        ,  2.78253948,  7.74252597],
#        [ 1.        ,  2.01072375,  4.04300999],
#        [ 1.        ,  2.257379  ,  5.09575995],
#        [ 1.        , -0.61073606,  0.37299853],
#        [ 1.        , -1.65546619,  2.74056832],
#        [ 1.        ,  0.29897899,  0.08938844],
#        [ 1.        ,  2.51491446,  6.32479474],
#        [ 1.        , -1.84028855,  3.38666194],
#        [ 1.        ,  2.03696077,  4.14920917],
#        [ 1.        , -0.77290723,  0.59738558]])

# %%
lr.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
x_new = np.linspace(-3, 3, 200).reshape(200, 1)
y_new = lr.predict(poly.transform(x_new))

f, ax = plt.subplots()

ax.plot(x_new, y_new, "r-", linewidth=2, label="poly pred")
ax.scatter(x,y)
ax.set_xlabel("X")
ax.set_ylabel("Y")
plt.show()

# %%
y_pred = lr.predict(x_poly)
print(r2_score(y, y_pred))
# Out:
# 0.895075586790823
